# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load an example dataset
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
# Defining style
sns.set_style('white')
sns.set_context("paper", font_scale = 2)

# %% [markdown]
# # Histogram and KDE plots

# %%
g = sns.displot(data=tips, x="total_bill", kind="hist", bins = 50, aspect=1.5)

# %%
g.savefig('histogram.png', dpi=300)

# %%
g = sns.displot(data=tips, x="total_bill", kind="hist", kde = True, bins = 50, aspect=1.5)

# %%
g.savefig('histogramkde.png', dpi=300)

# %%
g = sns.displot(data=tips, x="total_bill", kind="kde", aspect=1.5)

# %%
g.savefig('kdeplot1.png', dpi=300)

# %%
g = sns.displot(data=tips, x="total_bill", kind="ecdf", aspect=1.5)

# %%
g.savefig('ecdf.png', dpi=300)

# %% [markdown]
# # Plots that shows every observations

# %% [markdown]
# ### Stripplot

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.stripplot(x = "day",
              y = "tip",
              data = tips,
              jitter = True,
              ax = ax,
              s = 8)

sns.despine(right = True)
plt.show()

# %%
fig.savefig('Stripplot.png', dpi=300)

# %% [markdown]
# ### Swarmplot

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.swarmplot(x = "day",
              y = "tip",
              data = tips,
              ax = ax,
              s = 8)

sns.despine(right = True)
plt.show()

# %%
fig.savefig('Swarmplot.png', dpi=300)

# %% [markdown]
# # Plots based on abstract representation

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.boxplot(x = "day",
            y = "tip",
            data = tips,
            ax = ax,
            hue = "sex")

sns.despine(right = True)
plt.show()

# %%
fig.savefig('boxplot1.png', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.boxplot(x = "day",
              y = "tip",
              data = tips,
              ax = ax,
              hue = "sex")
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, ["Men", "Woman"], title='Gender', fontsize=16, title_fontsize=20)
sns.despine(right = True)
plt.show()

# %%
fig.savefig('boxplot2.png', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.stripplot(x = "day",
              y = "tip",
              hue = "sex",
              data = tips,
              ax = ax,
              dodge=True,
              s = 8,
              marker="D",
              palette="Set2",
              alpha = 0.7)

sns.boxplot(x = "day",
              y = "tip",
              data = tips,
              ax = ax,
              hue = "sex")

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, ["Men", "Woman"], title='Gender', fontsize=16, title_fontsize=20)

sns.despine(right = True)

plt.show()

# %%
fig.savefig('boxplot+strpplot.png', dpi=300)

# %% [markdown]
# # Violin Plot

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.violinplot(x = "day",
              y = "tip",
              data = tips,
              ax = ax,
              hue = "sex")
handles, labels = ax.get_legend_handles_labels()
ax.legend(title='Gender', fontsize=16, title_fontsize=20)
sns.despine(right = True)
plt.show()

# %%
fig.savefig('violinplot.png', dpi=300)

# %% [markdown]
# ### Boxenplot

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.boxenplot(x = "day",
              y = "tip",
              data = tips,
              ax = ax,
              hue = "sex",
              palette="pastel")

handles, labels = ax.get_legend_handles_labels()
ax.legend(title='Gender', fontsize=16, title_fontsize=20)

sns.despine(right = True)

plt.show()

# %%
fig.savefig('boxenplot.png', dpi=300)

# %% [markdown]
# # Statistical Plots

# %% [markdown]
# ### Count Plot

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.countplot(x = "sex",
              data = tips,
              ax = ax,
              hue = "smoker",
              palette="Set1")

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, ["Yes", "No"], title='Smoker', fontsize=16, title_fontsize=20)

sns.despine(right = True)

plt.show()

# %%
fig.savefig('countplot.png', dpi=300)

# %% [markdown]
# ### Point plot

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.pointplot(x = "day",
              y = "total_bill",
              data = tips,
              ax = ax,
              hue = "sex",
              capsize=.1,
              palette="Set1",
              dodge = 0.2)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, ["Men", "Women"], title='Gender', fontsize=16, title_fontsize=20)

sns.despine(right = True)

plt.show()

# %%
fig.savefig('pointplot.png', dpi=300)

# %% [markdown]
# ### Barplot

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(x = "day",
              y = "tip",
              data = tips,
              ax = ax,
              hue = "sex",
              palette="pastel")

handles, labels = ax.get_legend_handles_labels()
ax.legend(title='Gender', fontsize=16, title_fontsize=20)

sns.despine(right = True)

plt.show()

# %%
fig.savefig('barplot1.png', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(x = "day",
              y = "tip",
              data = tips,
              ax = ax,
              hue = "sex",
              palette="pastel",
              estimator = np.sum,
              ci = None)

handles, labels = ax.get_legend_handles_labels()
ax.legend(title='Gender', fontsize=16, title_fontsize=20)

sns.despine(right = True)

plt.show()

# %%
fig.savefig('barplot2.png', dpi=300)

# %% [markdown]
# # Relational plot

# %% [markdown]
# ### Scatter plot

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.scatterplot(x = "total_bill",
              y = "tip",
              data = tips,
              ax = ax,
              hue = "sex",
              s = 50)

sns.despine(right = True)
plt.show()

# %%
fig.savefig('scatterplot.png', dpi=300)

# %%
# Display a regression plot for Tuition

fig, ax = plt.subplots(figsize=(10, 6))

sns.regplot(x='total_bill',
            y="tip",
            data=tips,
            marker='D',
            color='blue')

sns.despine(right = True)

plt.show()
plt.clf()

# %%
fig.savefig('regressionplot.png', dpi=300)

# %%
# Display a regression plot for Tuition
from scipy import stats

fig, ax = plt.subplots(figsize=(10, 6))

# get coeffs of linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(tips['total_bill'], tips['tip'])

sns.regplot(x='total_bill',
            y="tip",
            data=tips,
            marker='D',
            color='blue', 
            line_kws={'label':"tip = {0:.2f} + {1:.2f} * total_bill".format(intercept, slope)})

sns.despine(right = True)

# plot legend
ax.legend(fontsize=16)

plt.show()
plt.clf()

# %%
fig.savefig('regressionplot1.png', dpi=300)

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(tips['total_bill'], tips['tip'])
print("slope: ", slope, "intercept: ", intercept)
# Out:
# slope:  0.1050245173843534 intercept:  0.9202696135546726

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.residplot(x='total_bill',
            y="tip",
            data=tips,
            color='blue')
sns.despine(right = True)

plt.show()
plt.clf()

# %%
fig.savefig('residplot.png', dpi=300)

# %%
auto = pd.read_csv("auto-mpg.csv")
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
fig, ax = plt.subplots(figsize=(12, 8))


# Generate a scatter plot of 'weight' and 'mpg' using skyblue circles
sns.scatterplot(auto['weight'],
                auto['mpg'],
                label='data points',
                s = 50,
                color='skyblue',
                marker='o',
                ax = ax)

# Plot in blue a linear regression of order 1 between 'weight' and 'mpg'
sns.regplot(x='weight',
            y='mpg',
            data=auto,
            scatter=None,
            color='blue',
            label='order 1')

# Plot in green a linear regression of order 2 between 'weight' and 'mpg'
sns.regplot(x='weight',
            y='mpg',
            data=auto,
            scatter=None,
            order=2,
            color='red',
            label='order 2',
            ax = ax)

sns.despine(right = True)

# Add a legend and display the plot
plt.legend(loc='upper right')
plt.show()

# %%
fig.savefig('nonlinear_reg.png', dpi=300)

# %% [markdown]
# ### lmplot

# %%
# Create a regression plot using hue

g = sns.lmplot(x='total_bill',
            y="tip",
            data=tips,
            hue='sex',
            markers=["o", "x"],
            palette=dict(Male="blue", Female="red"),
            size=7,
            legend=None)

plt.legend(title='Gender', loc='upper left', labels=['Male', 'Female'], title_fontsize = 20)
sns.despine(right = True)

plt.show()
plt.clf()

# %% [markdown]
# ### GLM plot

# %%
tips["big_tip"] = np.where(tips.tip > 3, 1, 0)

g = sns.lmplot(x="total_bill", y="big_tip", data=tips,
                 logistic=True, n_boot=500, y_jitter=.03, aspect = 1.2)

# %%
g.savefig('logistic_regression_plot.png', dpi=300)

# %% [markdown]
# # Time Series Plots

# %%
sales_data = pd.read_csv("Sales_dataset.csv", parse_dates=True, index_col = 0)
sales_data.head()
# Out:
#              Sales  AdBudget    GDP
# Date
# 1981-03-01  1020.2     659.2  251.8
# 1981-06-01   889.2     589.0  290.9
# 1981-09-01   795.0     512.5  290.8
# 1981-12-01  1003.9     614.1  292.4
# 1982-03-01  1057.7     647.2  279.1

# %%
# Define a function called plot_timeseries
def timeseries_plot(axes, x, y, color, xlabel, ylabel):

  # Plot the inputs x, y in the provided color
  axes.plot(x, y, color=color)

  # Set the x-axis label
  axes.set_xlabel(xlabel)

  # Set the y-axis label
  axes.set_ylabel(ylabel, color=color)

  # Set the colors tick params for y-axis
  axes.tick_params('y', colors=color)

# %%
# Defining style
sns.set_style('white')
sns.set_context("paper", font_scale = 2)   

fig, ax = plt.subplots(figsize = (12, 8))

timeseries_plot(ax, sales_data.index, sales_data["Sales"], "blue", "Time (years)", "Sales")
sns.despine(right = True)

plt.show()

# %%
fig.savefig('timeseries1.png', dpi=300)

# %%
# Defining style
sns.set_style('white')
sns.set_context("paper", font_scale = 2)   

fig, ax = plt.subplots(figsize = (12, 8))

timeseries_plot(ax, sales_data.index, sales_data["Sales"], "blue", "Time (years)", "Sales")

# Create a twin Axes that share the x
ax2 = ax.twinx()

timeseries_plot(ax2, sales_data.index, sales_data["GDP"], "red", "Time (years)", "GDP")

plt.show()

# %%
fig.savefig('timeseries2.png', dpi=300)

# %% [markdown]
# # Heat Maps

# %%
#Crosstab
crosstab1 = pd.crosstab(index=tips['day'],
                        columns=tips['sex'],
                        values=tips['tip'],
                        aggfunc='mean')
crosstab1
# Out:
# sex     Male      Female
# day
# Thur  2.980333  2.575625
# Fri   2.693000  2.781111
# Sat   3.083898  2.801786
# Sun   3.220345  3.367222

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.heatmap(crosstab1,
            annot=True,
            cbar=True,
            cmap = sns.color_palette("Reds", 8),
            linewidths=0.3,
            ax = ax)

# Rotate tick marks for visibility
plt.yticks(rotation=0)
plt.xticks(rotation=90)

plt.tight_layout()

#Show the plot
plt.show()

# %%
fig.savefig('heatmap.png', dpi=300)
